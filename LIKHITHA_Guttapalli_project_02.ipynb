# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Set working directory
# %cd /content/drive/MyDrive/Research
# Out:
# /content/drive/MyDrive/Research

# %%
import pandas as pd
import numpy as np
import seaborn as sns

df = pd.read_csv('all_accelerometer_data_pids_13.csv')
df
# Out:
#                    time     pid         x         y         z
# 0                     0  JB3156  0.000000  0.000000  0.000000
# 1                     0  CC6740  0.000000  0.000000  0.000000
# 2         1493733882409  SA0297  0.075800  0.027300 -0.010200
# 3         1493733882455  SA0297 -0.035900  0.079400  0.003700
# 4         1493733882500  SA0297 -0.242700 -0.086100 -0.016300
# ...                 ...     ...       ...       ...       ...
# 14057562  1493829248196  CC6740 -0.133956  0.124726 -0.010736
# 14057563  1493829248220  CC6740 -0.100764  0.180872  0.046449
# 14057564  1493829248245  CC6740 -0.131853  0.195934  0.181088
# 14057565  1493829248270  CC6740 -0.149704  0.194482  0.202393
# 14057566  1493829248294  CC6740 -0.107288  0.153548  0.168595
#
# [14057567 rows x 5 columns]

# %% [markdown]
# In the above I have read the accelerometer_data_pid

# %%
df_acc_subset =df[df['pid'] == 'SA0297']
df_acc_subset
# Out:
#                    time     pid       x       y       z
# 2         1493733882409  SA0297  0.0758  0.0273 -0.0102
# 3         1493733882455  SA0297 -0.0359  0.0794  0.0037
# 4         1493733882500  SA0297 -0.2427 -0.0861 -0.0163
# 5         1493733883945  SA0297 -0.2888  0.0514 -0.0145
# 6         1493733883953  SA0297 -0.0413 -0.0184 -0.0105
# ...                 ...     ...     ...     ...     ...
# 13933849  1493824735596  SA0297 -0.0107  0.0801  0.0840
# 13933852  1493824735641  SA0297  0.0132  0.0835  0.0493
# 13933855  1493824735686  SA0297  0.0480 -0.0071  0.1374
# 13933858  1493824735731  SA0297  0.0597 -0.0426 -0.1090
# 13933860  1493824735776  SA0297 -0.0061 -0.0700 -0.0018
#
# [962901 rows x 5 columns]

# %% [markdown]
# from the above large dataset I am considering a single dataset so that I have filtered one subset that has pid as SA0297.

# %%
df_cleantac = pd.read_csv('SA0297_clean_TAC.csv')
df_cleantac
# Out:
#      timestamp  TAC_Reading
# 0   1493716723    -0.010229
# 1   1493718546    -0.002512
# 2   1493718863     0.003249
# 3   1493719179     0.005404
# 4   1493719495     0.003377
# 5   1493719811    -0.001451
# 6   1493720127    -0.005816
# 7   1493720443    -0.006248
# 8   1493720759    -0.001631
# 9   1493721075     0.005332
# 10  1493721391     0.009407
# 11  1493721707     0.006597
# 12  1493723525    -0.002201
# 13  1493725342    -0.010741
# 14  1493727159    -0.011314
# 15  1493728977    -0.000636
# 16  1493730802     0.016699
# 17  1493732624     0.030566
# 18  1493734448     0.032672
# 19  1493736273     0.023972
# 20  1493738100     0.016196
# 21  1493739942     0.025131
# 22  1493741783     0.059263
# 23  1493743607     0.111503
# 24  1493745449     0.160592
# 25  1493747291     0.182644
# 26  1493749138     0.166101
# 27  1493750985     0.120321
# 28  1493752827     0.071503
# 29  1493754671     0.047758
# 30  1493756515     0.062414
# 31  1493758342     0.106077
# ...

# %%
df_acc_subset['timestamp'] = df_acc_subset['time']//1000
df_acc_subset
# Out:
# <ipython-input-7-426c0628305f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_acc_subset['timestamp'] = df_acc_subset['time']//1000
#                    time     pid       x       y       z   timestamp
# 2         1493733882409  SA0297  0.0758  0.0273 -0.0102  1493733882
# 3         1493733882455  SA0297 -0.0359  0.0794  0.0037  1493733882
# 4         1493733882500  SA0297 -0.2427 -0.0861 -0.0163  1493733882
# 5         1493733883945  SA0297 -0.2888  0.0514 -0.0145  1493733883
# 6         1493733883953  SA0297 -0.0413 -0.0184 -0.0105  1493733883
# ...                 ...     ...     ...     ...     ...         ...
# 13933849  1493824735596  SA0297 -0.0107  0.0801  0.0840  1493824735
# ...

# %% [markdown]
# the time value in accelerometer data and timestamp in clean data are not compatiable to perform various methods as they both are measured in different units even though they mean same so we are converting the time to timestamp using above formula.

# %%
result_data = pd.merge(df_acc_subset, df_cleantac,how = "inner",on='timestamp')
result_data
# Out:
#               time     pid       x       y       z   timestamp  TAC_Reading
# 0    1493734448017  SA0297  0.1312  0.0432  0.0034  1493734448     0.032672
# 1    1493734448062  SA0297  0.2734  0.1197  0.0968  1493734448     0.032672
# 2    1493734448107  SA0297  0.1514  0.1886  0.0375  1493734448     0.032672
# 3    1493734448156  SA0297 -0.0914  0.0496  0.0534  1493734448     0.032672
# 4    1493734448197  SA0297 -0.7935 -0.5184  0.3967  1493734448     0.032672
# ..             ...     ...     ...     ...     ...         ...          ...
# 391  1493806094780  SA0297 -0.0012  0.0006 -0.0058  1493806094    -0.021275
# 392  1493806094825  SA0297 -0.0025 -0.0006 -0.0056  1493806094    -0.021275
# 393  1493806094871  SA0297 -0.0012  0.0002 -0.0043  1493806094    -0.021275
# 394  1493806094915  SA0297 -0.0012 -0.0007 -0.0040  1493806094    -0.021275
# 395  1493806094960  SA0297 -0.0000 -0.0007 -0.0060  1493806094    -0.021275
#
# [396 rows x 7 columns]

# %% [markdown]
# the result_data above is the merged data of accelerometer and clean_tac data

# %%
import matplotlib.pyplot as plt
# Create subplots for each component
fig, ax = plt.subplots(4,1,figsize=(10, 10))
#for x and timestamp
ax[0].plot(result_data['timestamp'], result_data['x'], label='X', color = 'blue')
ax[0].set_xlabel('timestamp')
ax[0].set_ylabel('x values')
ax[0].set_title('graph of x and timestamp')

#y and timestamp
ax[1].plot(result_data['timestamp'], result_data['y'], label='Y', color = 'purple')
ax[1].set_xlabel('timestamp')
ax[1].set_ylabel('y values')
ax[1].set_title('graph of y and timestamp')

#z and timestamp
ax[2].plot(result_data['timestamp'], result_data['z'], label='Z', color = 'red')
ax[2].set_xlabel('timestamp')
ax[2].set_ylabel('z values')
ax[2].set_title('graph of y and timestamp')

#tac_reading and timestamp
ax[3].plot(result_data['timestamp'], result_data['TAC_Reading'], label='X', color = 'black')
ax[3].set_xlabel('timestamp')
ax[3].set_ylabel('TAC_Reading')
ax[3].set_title('graph of tac and timestamp')
# Out:
# Text(0.5, 1.0, 'graph of tac and timestamp')

# %% [markdown]
# The above is plotting of X,Y,Z Over timestamp .the above graphs doesn't prove accurate result as we expect. so for more accurate plotting and correct result below i have worked on time_indices with sample rate as 40 HZ for result_data .

# %%
time_indices = np.arange(result_data['x'].size)/40
time_indices
# Out:
# array([0.   , 0.025, 0.05 , 0.075, 0.1  , 0.125, 0.15 , 0.175, 0.2  ,
#        0.225, 0.25 , 0.275, 0.3  , 0.325, 0.35 , 0.375, 0.4  , 0.425,
#        0.45 , 0.475, 0.5  , 0.525, 0.55 , 0.575, 0.6  , 0.625, 0.65 ,
#        0.675, 0.7  , 0.725, 0.75 , 0.775, 0.8  , 0.825, 0.85 , 0.875,
#        0.9  , 0.925, 0.95 , 0.975, 1.   , 1.025, 1.05 , 1.075, 1.1  ,
#        1.125, 1.15 , 1.175, 1.2  , 1.225, 1.25 , 1.275, 1.3  , 1.325,
#        1.35 , 1.375, 1.4  , 1.425, 1.45 , 1.475, 1.5  , 1.525, 1.55 ,
#        1.575, 1.6  , 1.625, 1.65 , 1.675, 1.7  , 1.725, 1.75 , 1.775,
#        1.8  , 1.825, 1.85 , 1.875, 1.9  , 1.925, 1.95 , 1.975, 2.   ,
#        2.025, 2.05 , 2.075, 2.1  , 2.125, 2.15 , 2.175, 2.2  , 2.225,
#        2.25 , 2.275, 2.3  , 2.325, 2.35 , 2.375, 2.4  , 2.425, 2.45 ,
#        2.475, 2.5  , 2.525, 2.55 , 2.575, 2.6  , 2.625, 2.65 , 2.675,
#        2.7  , 2.725, 2.75 , 2.775, 2.8  , 2.825, 2.85 , 2.875, 2.9  ,
# ...

# %% [markdown]
# plotting of graph for X,Y,Z over timeindices

# %%
import matplotlib.pyplot as plt
# Create subplots for each component
fig, ax = plt.subplots(4,1,figsize=(10, 10))
#for x and timestamp
ax[0].plot(time_indices, result_data['x'], label='X', color = 'blue')
ax[0].set_xlabel('time_indices')
ax[0].set_ylabel('x values')
ax[0].set_title('graph of x and timestamp')

#y and timestamp
ax[1].plot(time_indices, result_data['y'], label='Y', color = 'purple')
ax[1].set_xlabel('time_indices')
ax[1].set_ylabel('y values')
ax[1].set_title('graph of y and timestamp')

#z and timestamp
ax[2].plot(time_indices, result_data['z'], label='Z', color = 'red')
ax[2].set_xlabel('time_indices')
ax[2].set_ylabel('z values')
ax[2].set_title('graph of y and timestamp')

#tac_reading and timestamp
ax[3].plot(time_indices, result_data['TAC_Reading'], label='X', color = 'black')
ax[3].set_xlabel('time_indices')
ax[3].set_ylabel('TAC_Reading')
ax[3].set_title('graph of tac and timestamp')
# Out:
# Text(0.5, 1.0, 'graph of tac and timestamp')

# %%
plot_newdata = pd.DataFrame({'time indices':time_indices,'X':result_data['x'],'TAC':result_data['TAC_Reading']})

# %% [markdown]
# newdata consist of timeindicies values ,x and tac data .

# %%
plot_newdata
# Out:
#      time indices       X       TAC
# 0           0.000  0.1312  0.032672
# 1           0.025  0.2734  0.032672
# 2           0.050  0.1514  0.032672
# 3           0.075 -0.0914  0.032672
# 4           0.100 -0.7935  0.032672
# ..            ...     ...       ...
# 391         9.775 -0.0012 -0.021275
# 392         9.800 -0.0025 -0.021275
# 393         9.825 -0.0012 -0.021275
# 394         9.850 -0.0012 -0.021275
# 395         9.875 -0.0000 -0.021275
#
# [396 rows x 3 columns]

# %%
sns.lineplot(x='time indices', y='X',data=plot_newdata)
# Out:
# <Axes: xlabel='time indices', ylabel='X'>

# %%
# !pip install ordpy

# %% [markdown]
# from the above plot_newdata I am grouping the X values where the tac is same in to separate groups where I got 17 x-groups from the graph using permutation entropy and complexity. This is helpful to find the frequency of value in the data and timeseries. permutations here will also be helpful to find the irregularity in any pattern.

# %%
import numpy as np
import ordpy
from matplotlib import pylab as plt


# Assuming your data is loaded into a DataFrame named df

# Group the data by TAC reading
newgroup_data = plot_newdata.groupby('TAC')

plot_newdata.sort_values(by='TAC', inplace=True)

x_groups = plot_newdata.groupby('TAC')['X'].apply(list)

# Calculate Permutation Entropy and Complexity for each group
results = []
for tac_value, x_group in x_groups.items():
    pe = ordpy.permutation_entropy(x_group, 3)
    comp = pe / np.log(len(x_group))
    results.append({'TAC Value': tac_value, 'Permutation Entropy': pe, 'Complexity': comp})

# Create a DataFrame from the results
results_df = pd.DataFrame(results)

sns.lineplot(results_df['Complexity'])
# Plot Permutation Entropy and Complexity
# Out:
# <Axes: ylabel='Complexity'>

# %%
results_df
# Out:
#      TAC Value  Permutation Entropy  Complexity
# 0    -0.021275             0.987529    0.319481
# 1    -0.004768             0.961013    0.310903
# 2    -0.004448             0.896981    0.243158
# 3    -0.003344             0.993914    0.269435
# 4    -0.003296             0.982944    0.266462
# ..         ...                  ...         ...
# 151   0.176895             0.991801    0.270721
# 152   0.182644             0.939857    0.299748
# 153   0.193018             0.944275    0.261506
# 154   0.206761             0.937232    0.254070
# 155   0.217373             0.993914    0.269435
#
# [156 rows x 3 columns]

# %%
plot_newdata['TAC_CLASSIFY'] = '0'

# %% [markdown]
# I have created a separate column in the plot_newdata to categorize between the heavy drinking and non drinking or less drinking which is TAC_CLASSIFY.

# %%
plot_newdata.loc[plot_newdata['TAC'] > 0.08, 'TAC_CLASSIFY'] = '1'
plot_newdata
# Out:
#      time indices       X       TAC TAC_CLASSIFY
# 395         9.875 -0.0000 -0.021275            0
# 394         9.850 -0.0012 -0.021275            0
# 374         9.350 -0.0015 -0.021275            0
# 375         9.375 -0.0010 -0.021275            0
# 376         9.400 -0.0012 -0.021275            0
# ..            ...     ...       ...          ...
# 26          0.650 -0.0020  0.182644            1
# 25          0.625  0.0020  0.182644            1
# 22          0.550 -0.0016  0.182644            1
# 24          0.600  0.0019  0.182644            1
# 32          0.800 -0.0002  0.182644            1
#
# [396 rows x 4 columns]

# %% [markdown]
# In the above code I have considered TAC_CLASSIFY to differentiate between sober and intoxicated here O indicate intoxicated and 1 as sober case. I have differentiate this using TAC if its less than 0.08 the person is intoxicated and if its >0.08 the person is sober.

# %%
results_df.loc[results_df['TAC Value']>0.08, 'TAC_CLASSIFY']='1'
results_df.loc[results_df['TAC Value']<0.08, 'TAC_CLASSIFY']='0'

results_df
# Out:
#      TAC Value  Permutation Entropy  Complexity TAC_CLASSIFY
# 0    -0.021275             0.987529    0.319481            0
# 1    -0.004768             0.961013    0.310903            0
# 2    -0.004448             0.896981    0.243158            0
# 3    -0.003344             0.993914    0.269435            0
# 4    -0.003296             0.982944    0.266462            0
# ..         ...                  ...         ...          ...
# 151   0.176895             0.991801    0.270721            1
# 152   0.182644             0.939857    0.299748            1
# 153   0.193018             0.944275    0.261506            1
# 154   0.206761             0.937232    0.254070            1
# 155   0.217373             0.993914    0.269435            1
#
# [156 rows x 4 columns]

# %% [markdown]
# Here i have merged the tac_classify(sober/intoxicated) along with permutation entropy and complexity values.the permutation entropy and complexity has provided the best results as it works well with multitude of timeseries task analysis

# %%
import seaborn as sns

sns.scatterplot(x='Permutation Entropy', y='Complexity',hue=results_df['TAC_CLASSIFY'], data=results_df)
# Out:
# <Axes: xlabel='Permutation Entropy', ylabel='Complexity'>

# %%
import seaborn as sns
colour_palette = ['blue', 'black', 'brown','red','yellow']
sns.scatterplot(x='time indices', y='TAC', hue='TAC_CLASSIFY',palette = colour_palette, data=plot_newdata)
plt.title('Scatterplot of TAC')
plt.xlabel('time indicies')
plt.ylabel('TAC')
plt.legend()
plt.show()
# Out:
# <ipython-input-19-6372ebca7023>:3: UserWarning: The palette list has more values (5) than needed (2), which may not be intended.
#   sns.scatterplot(x='time indices', y='TAC', hue='TAC_CLASSIFY',palette = colour_palette, data=plot_newdata)

# %% [markdown]
# To indentify the sober and intoxicated mean TAC_CLASSIFY between timestamp and tac i have used scatter plotting to easily differentiate and correlation between the data

# %%
df1 = pd.read_csv('CLEAN_TAC_finall.csv')
df1
# Out:
#       timestamp  TAC_Reading     pid
# 0    1493718714    -0.000482  BK7610
# 1    1493720697     0.001573  BK7610
# 2    1493721027     0.002144  BK7610
# 3    1493721357     0.000877  BK7610
# 4    1493721686    -0.001145  BK7610
# ..          ...          ...     ...
# 710  1493797974     0.029049  SF3079
# 711  1493799820     0.016286  SF3079
# 712  1493801652     0.004243  SF3079
# 713  1493803481    -0.001995  SF3079
# 714  1493805310    -0.002919  SF3079
#
# [715 rows x 3 columns]

# %% [markdown]
# df1 is the complete clean_tac data file.

# %%
df
# Out:
#                    time     pid         x         y         z
# 0                     0  JB3156  0.000000  0.000000  0.000000
# 1                     0  CC6740  0.000000  0.000000  0.000000
# 2         1493733882409  SA0297  0.075800  0.027300 -0.010200
# 3         1493733882455  SA0297 -0.035900  0.079400  0.003700
# 4         1493733882500  SA0297 -0.242700 -0.086100 -0.016300
# ...                 ...     ...       ...       ...       ...
# 14057562  1493829248196  CC6740 -0.133956  0.124726 -0.010736
# 14057563  1493829248220  CC6740 -0.100764  0.180872  0.046449
# 14057564  1493829248245  CC6740 -0.131853  0.195934  0.181088
# 14057565  1493829248270  CC6740 -0.149704  0.194482  0.202393
# 14057566  1493829248294  CC6740 -0.107288  0.153548  0.168595
#
# [14057567 rows x 5 columns]

# %%
df['timestamp'] = df['time']//1000
df
# Out:
#                    time     pid         x         y         z   timestamp
# 0                     0  JB3156  0.000000  0.000000  0.000000           0
# 1                     0  CC6740  0.000000  0.000000  0.000000           0
# 2         1493733882409  SA0297  0.075800  0.027300 -0.010200  1493733882
# 3         1493733882455  SA0297 -0.035900  0.079400  0.003700  1493733882
# 4         1493733882500  SA0297 -0.242700 -0.086100 -0.016300  1493733882
# ...                 ...     ...       ...       ...       ...         ...
# 14057562  1493829248196  CC6740 -0.133956  0.124726 -0.010736  1493829248
# 14057563  1493829248220  CC6740 -0.100764  0.180872  0.046449  1493829248
# 14057564  1493829248245  CC6740 -0.131853  0.195934  0.181088  1493829248
# 14057565  1493829248270  CC6740 -0.149704  0.194482  0.202393  1493829248
# 14057566  1493829248294  CC6740 -0.107288  0.153548  0.168595  1493829248
#
# [14057567 rows x 6 columns]

# %% [markdown]
# Here also I have coverted the time to timestamp for good compatiablity

# %%
import pandas as pd

merged_df = pd.merge(df1, df, on=["pid", "timestamp"], how="inner")

# %%
merged_df
# Out:
#        timestamp  TAC_Reading     pid           time       x       y       z
# 0     1493737046     0.065357  BK7610  1493737046023  0.1410 -0.2686 -0.1372
# 1     1493737046     0.065357  BK7610  1493737046063  0.1714 -0.2722 -0.1208
# 2     1493737046     0.065357  BK7610  1493737046073  0.3328 -0.1353 -0.2548
# 3     1493737046     0.065357  BK7610  1493737046101  0.2822 -0.0375 -0.2816
# 4     1493737046     0.065357  BK7610  1493737046134  0.1847  0.1813 -0.2680
# ...          ...          ...     ...            ...     ...     ...     ...
# 6142  1493781346     0.159026  SF3079  1493781346865  0.1188  0.0456 -0.0480
# 6143  1493781346     0.159026  SF3079  1493781346909  0.1342 -0.0594  0.1822
# 6144  1493781346     0.159026  SF3079  1493781346925  0.1356 -0.0877  0.1830
# 6145  1493781346     0.159026  SF3079  1493781346944  0.1117 -0.0822  0.0917
# 6146  1493781346     0.159026  SF3079  1493781346974  0.0551 -0.0908  0.0152
#
# [6147 rows x 7 columns]

# %%
grouped_dataset = merged_df.groupby('pid')

plt.figure(figsize = (10,10))
for pid, group_data in grouped_dataset:
    plt.plot(group_data['timestamp'], group_data['TAC_Reading'], label=f'PID {pid}')

plt.xlabel('Timestamp')
plt.ylabel('TAC')
plt.title('Time Series ')
plt.legend()
plt.show()

# %% [markdown]
# the above timeseries graph between timestamp and TAC for all the pids in dataset shows the continous changes in data values over time

# %%
merged_df['TAC_CLASSIFY'] = merged_df['TAC_Reading'].apply(lambda x: 0 if x < 0.08 else 1)
merged_df
# Out:
#        timestamp  TAC_Reading     pid           time       x       y       z  \
# 0     1493737046     0.065357  BK7610  1493737046023  0.1410 -0.2686 -0.1372
# 1     1493737046     0.065357  BK7610  1493737046063  0.1714 -0.2722 -0.1208
# 2     1493737046     0.065357  BK7610  1493737046073  0.3328 -0.1353 -0.2548
# 3     1493737046     0.065357  BK7610  1493737046101  0.2822 -0.0375 -0.2816
# 4     1493737046     0.065357  BK7610  1493737046134  0.1847  0.1813 -0.2680
# ...          ...          ...     ...            ...     ...     ...     ...
# 6142  1493781346     0.159026  SF3079  1493781346865  0.1188  0.0456 -0.0480
# 6143  1493781346     0.159026  SF3079  1493781346909  0.1342 -0.0594  0.1822
# 6144  1493781346     0.159026  SF3079  1493781346925  0.1356 -0.0877  0.1830
# 6145  1493781346     0.159026  SF3079  1493781346944  0.1117 -0.0822  0.0917
# 6146  1493781346     0.159026  SF3079  1493781346974  0.0551 -0.0908  0.0152
#
#       TAC_CLASSIFY
# 0                0
# ...

# %%
#permutation entropy for merged_data
pe_data = merged_df.groupby('TAC_Reading')

merged_df.sort_values(by='TAC_Reading', inplace=True)

x_groups = merged_df.groupby('TAC_Reading')['x'].apply(list)

# Calculate Permutation Entropy and Complexity for each group
results = []
for tac_value, x_group in x_groups.items():
    pe = ordpy.permutation_entropy(x_group, 3)
    comp = pe / np.log(len(x_group))
    results.append({'pid': pid, 'Permutation Entropy': pe, 'Complexity': comp})

# Create a DataFrame from the results
resultant_df = pd.DataFrame(results)

sns.lineplot(results_df['Complexity'])
# Out:
# <Axes: ylabel='Complexity'>

# %% [markdown]
# I have plotted a graph for all the merged data to see the permutation entropy and complexity.

# %%
resultant_df
# Out:
#         pid  Permutation Entropy  Complexity
# 0    SF3079             0.994579    0.321762
# 1    SF3079             0.924759    0.299174
# 2    SF3079             0.986890    0.267531
# 3    SF3079             0.976511    0.264718
# 4    SF3079             0.973319    0.263852
# ..      ...                  ...         ...
# 151  SF3079             0.996489    0.272000
# 152  SF3079             0.950727    0.303214
# 153  SF3079             0.984234    0.272572
# 154  SF3079             0.984552    0.266897
# 155  SF3079             0.959200    0.260025
#
# [156 rows x 3 columns]

# %%
grouped_piddata = merged_df.groupby('pid')

plt.figure(figsize=(10, 6))  # Adjust figure size as needed
for pid, group_data in grouped_piddata:
    color = 'blue' if 1 in group_data['TAC_CLASSIFY'].values else 'orange'
    plt.scatter(group_data['timestamp'], group_data['TAC_Reading'], label=f'PID {pid}', color=color)

plt.xlabel('Timestamp')
plt.ylabel('TAC')
plt.title('Scatter Plot for Different PIDs in total data')
plt.legend()
plt.show()

# %% [markdown]
# This scatterplot is for all the pids in dataset.It will show the people with heavy drinking (sober) and intoxidate in graphical representation.
